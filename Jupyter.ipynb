# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
np.random.seed(42)

# %% [markdown]
# # a) Load the dataset

# %%
df = pd.read_csv('weather_forecast_data.csv')
df
# Out:
#       Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 0       19.096119  71.651723   14.782324    48.699257   987.954760  no rain
# 1       27.112464  84.183705   13.289986    10.375646  1035.430870  no rain
# 2       20.433329  42.290424    7.216295     6.673307  1033.628086  no rain
# 3       19.576659  40.679280    4.568833    55.026758  1038.832300  no rain
# 4       19.828060  93.353211    0.104489    30.687566  1009.423717  no rain
# ...           ...        ...         ...          ...          ...      ...
# 2495    14.684023  82.054139    8.751728    58.939058  1003.418337     rain
# 2496    20.754521  92.099534   17.305508    70.889921  1049.801435     rain
# 2497    22.087516  71.530065    0.857918    84.162554  1039.664865     rain
# 2498    18.542453  97.451961    5.429309    54.643893  1014.769130     rain
# 2499    23.720338  89.592641    7.335604    50.501694  1032.378759     rain
#
# [2500 rows x 6 columns]

# %% [markdown]
# # b) Perform analysis on the dataset to:
# ## i) Check whether there are missing values

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  2475 non-null   float64
#  1   Humidity     2460 non-null   float64
#  2   Wind_Speed   2468 non-null   float64
#  3   Cloud_Cover  2467 non-null   float64
#  4   Pressure     2473 non-null   float64
#  5   Rain         2500 non-null   object
# dtypes: float64(5), object(1)
# memory usage: 117.3+ KB
# Temperature    25
# Humidity       40
# Wind_Speed     32
# Cloud_Cover    33
# Pressure       27
# Rain            0
# dtype: int64

# %% [markdown]
# ## ii) Check whether numeric features have the same scale

# %%
df.describe().T
# Out:
#               count         mean        std         min         25%  \
# Temperature  2475.0    22.573777   7.332397   10.001842   16.356603
# Humidity     2460.0    64.366909  19.973824   30.005071   47.183183
# Wind_Speed   2468.0     9.911826   5.780705    0.009819    4.782528
# Cloud_Cover  2467.0    49.808770  29.062298    0.015038   24.261914
# Pressure     2473.0  1014.409327  20.182257  980.014486  997.029601
#
#                      50%          75%          max
# Temperature    22.533110    28.984159    34.995214
# Humidity       64.090914    81.561021    99.997481
# Wind_Speed      9.908572    14.953142    19.999132
# Cloud_Cover    49.692078    75.417253    99.997795
# Pressure     1013.583677  1031.762839  1049.985593

# %% [markdown]
# ## iii) Visualize a pairplot where diagonal subplots are histograms

# %%
sns.pairplot(df)

# %% [markdown]
# ## iv) Visualize a correlation heatmap between numeric columns

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True,
            cmap='RdYlGn', vmin=-1, vmax=1)
# Out:
# <Axes: >
